# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

string = "shudiptotrafder@gmail.com"
patter = ".*@.*.com"
match = re.match(patter, string)
match.string
# Out:
# 'shudiptotrafder@gmail.com'

# %%
def is_valid_email(s):
    p = ".*.@.*.com"
    match = re.match(p, s)
    return match.string

# %%
is_valid_email("Someone@example.com")
# Out:
# 'Someone@example.com'

# %%
my_string = "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# %%
# Write a pattern to match sentence endings: sentence_endings
sentence_endings = r"[\!?.]"

# Split my_string on sentence endings and print the result
print(re.split(sentence_endings, my_string))
# Out:
# ["Let's write RegEx", "  Won't that be fun", '  I sure think so', '  Can you find 4 sentences', '  Or perhaps, all 19 words', '']

# %%
capitalized_words = r"[A-Z]\w+"
print(re.findall(capitalized_words, my_string))
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %%
spaces = r"\s+?"
print(re.split(spaces, my_string))
# Out:
# ["Let's", 'write', 'RegEx!', '', "Won't", 'that', 'be', 'fun?', '', 'I', 'sure', 'think', 'so.', '', 'Can', 'you', 'find', '4', 'sentences?', '', 'Or', 'perhaps,', 'all', '19', 'words?']

# %%
digits = r"\d+"
print(re.findall(digits, my_string))
# Out:
# ['4', '19']

# %%
n_digits = r"\D+"
print(re.findall(n_digits, my_string))
# Out:
# ["Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find ", ' sentences?  Or perhaps, all ', ' words?']
